# %%
import pandas as pd

import numpy as np

# %%
csv_path = "../OneDrive/desktop/BootCamp/Homework/zillowhomes.csv" 


zillow = pd.read_csv(csv_path,encoding="ISO-8859-1")

zillow
# Out:
#        RegionID  RegionName               City State  \
# 0         61639       10025           New York    NY
# 1         84654       60657            Chicago    IL
# 2         61637       10023           New York    NY
# 3         91982       77494               Katy    TX
# 4         84616       60614            Chicago    IL
# 5         93144       79936            El Paso    TX
# 6         91940       77449               Katy    TX
# 7         91733       77084            Houston    TX
# 8         61616       10002           New York    NY
# 9         61807       10467           New York    NY
# 10        84640       60640            Chicago    IL
# 11        62037       11226           New York    NY
# 12        97564       94109      San Francisco    CA
# 13        61630       10016           New York    NY
# 14        74101       37013          Nashville    TN
# 15        92593       78660       Pflugerville    TX
# 16        71831       32162       The Villages    FL
# ...

# %%
zillow.set_index("RegionID", inplace=True)

zillow.head()
# Out:
#           RegionName      City State                             Metro  \
# RegionID
# 61639          10025  New York    NY       New York-Newark-Jersey City
# 84654          60657   Chicago    IL          Chicago-Naperville-Elgin
# 61637          10023  New York    NY       New York-Newark-Jersey City
# 91982          77494      Katy    TX  Houston-The Woodlands-Sugar Land
# 84616          60614   Chicago    IL          Chicago-Naperville-Elgin
#
#                CountyName  SizeRank   1996-04    1996-05    1996-06   \
# RegionID
# 61639     New York County         1   168300.0   168400.0   168400.0
# 84654         Cook County         2   160000.0   161000.0   161700.0
# 61637     New York County         3   353100.0   353700.0   354200.0
# 91982       Harris County         4   210400.0   212200.0   212200.0
# 84616         Cook County         5   194400.0   196100.0   197300.0
#
#            1996-07     ...       2018-05    2018-06    2018-07    2018-08   \
# ...

# %%
zillow = zillow.drop(zillow.columns[[0]],axis=1)

zillow.head()





#zillow.drop("City", axis=1, inplace=True)
# Out:
#            1996-04    1996-05    1996-06    1996-07    1996-08    1996-09   \
# RegionID
# 61639      168300.0   168400.0   168400.0   168400.0   168400.0   168600.0
# 84654      160000.0   161000.0   161700.0   162000.0   162000.0   161600.0
# 61637      353100.0   353700.0   354200.0   354600.0   354900.0   355400.0
# 91982      210400.0   212200.0   212200.0   210700.0   208300.0   205500.0
# 84616      194400.0   196100.0   197300.0   197800.0   197700.0   196900.0
#
#            1996-10    1996-11    1996-12    1997-01     ...       2018-05   \
# RegionID                                                ...
# 61639      169200.0   170000.0   171500.0   173300.0    ...        1115700
# 84654      160800.0   159700.0   158500.0   157500.0    ...         350100
# 61637      356100.0   357100.0   358800.0   361100.0    ...        1501700
# 91982      202500.0   199800.0   198300.0   197300.0    ...         334400
# ...

# %%
zillow_new = pd.DataFrame(zillow)

zillow_new.head()
# Out:
#            1996-04    1996-05    1996-06    1996-07    1996-08    1996-09   \
# RegionID
# 61639      168300.0   168400.0   168400.0   168400.0   168400.0   168600.0
# 84654      160000.0   161000.0   161700.0   162000.0   162000.0   161600.0
# 61637      353100.0   353700.0   354200.0   354600.0   354900.0   355400.0
# 91982      210400.0   212200.0   212200.0   210700.0   208300.0   205500.0
# 84616      194400.0   196100.0   197300.0   197800.0   197700.0   196900.0
#
#            1996-10    1996-11    1996-12    1997-01     ...       2018-05   \
# RegionID                                                ...
# 61639      169200.0   170000.0   171500.0   173300.0    ...        1115700
# 84654      160800.0   159700.0   158500.0   157500.0    ...         350100
# 61637      356100.0   357100.0   358800.0   361100.0    ...        1501700
# 91982      202500.0   199800.0   198300.0   197300.0    ...         334400
# ...

# %%
zillow_new.pct_change(axis='columns')

zillow_pct = pd.DataFrame(zillow_new.pct_change(axis='columns')
)

zillow_pct.head()
# Out:
#            1996-04    1996-05    1996-06    1996-07    1996-08    1996-09   \
# RegionID
# 61639           NaN   0.000594   0.000000   0.000000   0.000000   0.001188
# 84654           NaN   0.006250   0.004348   0.001855   0.000000  -0.002469
# 61637           NaN   0.001699   0.001414   0.001129   0.000846   0.001409
# 91982           NaN   0.008555   0.000000  -0.007069  -0.011391  -0.013442
# 84616           NaN   0.008745   0.006119   0.002534  -0.000506  -0.004047
#
#            1996-10    1996-11    1996-12    1997-01     ...       2018-05   \
# RegionID                                                ...
# 61639      0.003559   0.004728   0.008824   0.010496    ...      -0.003839
# 84654     -0.004950  -0.006841  -0.007514  -0.006309    ...      -0.003699
# 61637      0.001970   0.002808   0.004761   0.006410    ...       0.003006
# 91982     -0.014599  -0.013333  -0.007508  -0.005043    ...       0.005412
# ...

# %%
zillow_pct
